# %%
import rospy
from utils.misc_utils import *
from sensor_msgs.msg import PointCloud2
import cv2
from matplotlib import pyplot as plt

# %%
rospy.init_node("object_contour_detection")

# %%
pc = rospy.wait_for_message("/hsrb/head_rgbd_sensor/depth_registered/rectified_points",PointCloud2,timeout=5)

# %%
points_data = ros_numpy.numpify(pc)
image_data = points_data['rgb'].view((np.uint8, 4))[..., [2, 1, 0]]   
image = cv2.cvtColor(image_data, cv2.COLOR_BGR2RGB)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(image)

# %%
canny = cv2.Canny(gray, canny_lower, canny_upper)
contours, hierarchy = cv2.findContours(canny, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    
mask = np.zeros(img.shape, dtype=np.uint8)
    
    #for c in contours:
        #cv2.fillConvexPoly(mask, c, (255,255,255))
cv2.drawContours(mask, contours, -1, (255,255,0), thickness=cv2.FILLED)
    #cv2.drawContours(img, contours, -1, (0,255,0), 0)
segmented = cv2.bitwise_and(img, mask)
